# %%
import pandas as pd

# !pip install pymongo

import pymongo


df = pd.read_csv('/content/sample_data/data.csv')

df.head()

# df should be converted into dict before we push it into mongoDB

data = df.to_dict(orient='records')

DB_NAME = "Proj1"
COLLECTION_NAME = "Proj1-Data"
COLLECTION_URL = "mongodb+srv://somg0703:3oCMnl8MSlLuA90A@cluster0.nkwkd.mongodb.net/?appName=Cluster0"

client = pymongo.MongoClient(COLLECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

rec = collection.insert_many(data)
